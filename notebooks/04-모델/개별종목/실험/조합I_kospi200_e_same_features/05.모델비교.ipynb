# %% [markdown]
# # 개별종목 조합I 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4178 | 0.3969 | +0.0210 | 0.3686 | 9/12 | 0.0885 | 0.3974 |
# | 2 | XGBoost | 0.4124 | 0.3969 | +0.0156 | 0.3678 | 7/12 | 0.0846 | 0.3920 |
# | 3 | LightGBM | 0.4084 | 0.3969 | +0.0115 | 0.3696 | 6/12 | 0.0794 | 0.3884 |
# | 4 | RandomForest | 0.3744 | 0.3969 | -0.0225 | 0.3558 | 3/12 | 0.0403 | 0.3617 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['I']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   9           0.750000  0.417827
# 1             XGBoost     12                   7           0.583333  0.412423
# 2            LightGBM     12                   6           0.500000  0.408366
# 3        RandomForest     12                   3           0.250000  0.374396
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.044176  0.368582           0.036701     0.273000
# 1           0.046501  0.367801           0.030384     0.273519
# 2           0.044157  0.369639           0.026340     0.287463
# 3           0.020226  0.355766           0.012753     0.320487
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.124874  ...   0.350246            0.055964          0.397380
# 1              0.128053  ...   0.346631            0.055728          0.392026
# 2              0.115217  ...   0.341860            0.053549          0.388434
# 3              0.055875  ...   0.321208            0.043326          0.361694
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.016642                              0.39685
# 1                   0.017246                              0.39685
# 2                   0.017259                              0.39685
# 3                   0.008351                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.020977
# 1                                   0.015573
# 2                                   0.011516
# 3                                  -0.022455
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.027845
# 1                                           0.027253
# 2                                           0.026795
# 3                                           0.037924
#
# [4 rows x 30 columns]
