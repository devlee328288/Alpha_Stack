# %% [markdown]
# # 개별종목 조합B 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | LightGBM ⭐ | 0.3999 | 0.3969 | +0.0030 | 0.3775 | 0.3310 | **0.3611** |
# | 2 | RandomForest | 0.3808 | 0.3969 | -0.0161 | 0.3636 | 0.3301 | **0.3549** |
# | 3 | XGBoost | 0.4043 | 0.3969 | +0.0074 | 0.3755 | 0.2974 | **0.3464** |
# | 4 | LogisticRegression | 0.4061 | 0.3969 | +0.0092 | 0.3741 | 0.2650 | **0.3324** |
#
# 별표는 합의한 핵심지표 조화평균이 가장 높은 모델입니다. Accuracy 단독 순위가 아니라
# 하락 Recall까지 함께 반영하므로, 중립이나 상승 한쪽으로만 쏠린 모델을 피합니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,936행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 5행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['B']["model_summary"])
display(comparison)
# Out:
#                 model  folds  accuracy  accuracy_fold_std  macro_f1  \
# 0            LightGBM     12  0.399903           0.039158  0.377462
# 1        RandomForest     12  0.380763           0.031539  0.363595
# 2             XGBoost     12  0.404251           0.036814  0.375504
# 3  LogisticRegression     12  0.406059           0.035977  0.374132
#
#    macro_f1_fold_std  down_recall  down_recall_fold_std  core_harmonic_mean  \
# 0           0.025339     0.330969              0.088581            0.361124
# 1           0.017345     0.330147              0.043534            0.354948
# 2           0.025603     0.297351              0.084844            0.346442
# 3           0.025402     0.264951              0.063846            0.332385
#
#    core_harmonic_mean_fold_std  training_majority_baseline_accuracy  \
# 0                     0.045917                             0.396868
# 1                     0.020381                             0.396868
# 2                     0.046949                             0.396868
# 3                     0.039419                             0.396868
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                      0.054978
# 1                                      0.054978
# 2                                      0.054978
# 3                                      0.054978
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402772
# 1                             0.402772
# 2                             0.402772
# 3                             0.402772
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049799
# 1                                      0.049799
# 2                                      0.049799
# 3                                      0.049799
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.003035
# 1                                  -0.016105
# 2                                   0.007383
# 3                                   0.009191
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.037501
# 1                                           0.034285
# 2                                           0.036040
# 3                                           0.038073
