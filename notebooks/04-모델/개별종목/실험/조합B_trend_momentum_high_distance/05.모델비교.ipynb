# %% [markdown]
# # 개별종목 조합B 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4062 | 0.3969 | +0.0093 | 0.3742 | 6/12 | 0.0805 | 0.3913 |
# | 2 | XGBoost | 0.4038 | 0.3969 | +0.0070 | 0.3747 | 6/12 | 0.0772 | 0.3899 |
# | 3 | LightGBM | 0.3986 | 0.3969 | +0.0017 | 0.3760 | 6/12 | 0.0750 | 0.3882 |
# | 4 | RandomForest | 0.3818 | 0.3969 | -0.0150 | 0.3670 | 5/12 | 0.0555 | 0.3666 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['B']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   6           0.500000  0.406156
# 1             XGBoost     12                   6           0.500000  0.403842
# 2            LightGBM     12                   6           0.500000  0.398577
# 3        RandomForest     12                   5           0.416667  0.381813
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.035951  0.374195           0.025158     0.264648
# 1           0.037558  0.374675           0.025896     0.295902
# 2           0.037890  0.376013           0.024268     0.328874
# 3           0.027329  0.366952           0.016499     0.336151
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.063429  ...   0.355638            0.055138          0.391276
# 1              0.086429  ...   0.359818            0.054154          0.389851
# 2              0.086206  ...   0.356606            0.050190          0.388234
# 3              0.043979  ...   0.330872            0.046811          0.366557
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.020358                              0.39685
# 1                   0.021352                              0.39685
# 2                   0.020133                              0.39685
# 3                   0.013327                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.009306
# 1                                   0.006992
# 2                                   0.001726
# 3                                  -0.015037
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.037950
# 1                                           0.036283
# 2                                           0.037812
# 3                                           0.036286
#
# [4 rows x 30 columns]
