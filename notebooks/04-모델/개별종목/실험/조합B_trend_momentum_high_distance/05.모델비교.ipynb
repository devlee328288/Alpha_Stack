# %% [markdown]
# # 개별종목 조합B 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | RandomForest ⭐ | 0.3713 | 0.3851 | -0.0138 | 0.3576 | 0.3327 | **0.3508** |
# | 2 | LightGBM | 0.3840 | 0.3851 | -0.0011 | 0.3647 | 0.3257 | **0.3489** |
# | 3 | XGBoost | 0.3870 | 0.3851 | +0.0019 | 0.3618 | 0.2870 | **0.3300** |
# | 4 | LogisticRegression | 0.3926 | 0.3851 | +0.0075 | 0.3650 | 0.2722 | **0.3244** |
#
# 별표는 합의한 핵심지표 조화평균이 가장 높은 모델입니다. Accuracy 단독 순위가 아니라
# 하락 Recall까지 함께 반영하므로, 중립이나 상승 한쪽으로만 쏠린 모델을 피합니다.
#
# ## 데이터 규모
#
# - 모델 행: 171,557행
# - 거래일: 3,552일
# - 후보에 포함된 종목: 162종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 5행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3851
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.3976
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['B']["model_summary"])
display(comparison)
# Out:
#                 model  folds  accuracy  accuracy_fold_std  macro_f1  \
# 0        RandomForest     12  0.371347           0.020744  0.357629
# 1            LightGBM     12  0.383982           0.027363  0.364729
# 2             XGBoost     12  0.387016           0.025976  0.361765
# 3  LogisticRegression     12  0.392645           0.027426  0.365049
#
#    macro_f1_fold_std  down_recall  down_recall_fold_std  core_harmonic_mean  \
# 0           0.012835     0.332679              0.052501            0.350847
# 1           0.018732     0.325674              0.099401            0.348912
# 2           0.016390     0.287037              0.105120            0.329953
# 3           0.018226     0.272250              0.098513            0.324384
#
#    core_harmonic_mean_fold_std  training_majority_baseline_accuracy  \
# 0                     0.017692                             0.385115
# 1                     0.032292                             0.385115
# 2                     0.043811                             0.385115
# 3                     0.041555                             0.385115
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                      0.056247
# 1                                      0.056247
# 2                                      0.056247
# 3                                      0.056247
#
#    validation_majority_oracle_accuracy  \
# 0                             0.397559
# 1                             0.397559
# 2                             0.397559
# 3                             0.397559
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.044893
# 1                                      0.044893
# 2                                      0.044893
# 3                                      0.044893
#
#    accuracy_minus_training_majority_baseline  \
# 0                                  -0.013768
# 1                                  -0.001133
# 2                                   0.001901
# 3                                   0.007530
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.043028
# 1                                           0.040578
# 2                                           0.040577
# 3                                           0.040442
