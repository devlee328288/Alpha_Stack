# %% [markdown]
# # 개별종목 조합E 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | XGBoost ⭐ | 0.4005 | 0.3969 | +0.0037 | 0.3642 | 6/12 | 0.0666 | 0.3797 |
# | 2 | LightGBM | 0.3952 | 0.3969 | -0.0016 | 0.3642 | 6/12 | 0.0614 | 0.3785 |
# | 3 | LogisticRegression | 0.3934 | 0.3969 | -0.0034 | 0.3634 | 3/12 | 0.0629 | 0.3798 |
# | 4 | RandomForest | 0.3779 | 0.3969 | -0.0189 | 0.3560 | 4/12 | 0.0423 | 0.3597 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['E']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0             XGBoost     12                   6           0.500000  0.400538
# 1            LightGBM     12                   6           0.500000  0.395203
# 2  LogisticRegression     12                   3           0.250000  0.393404
# 3        RandomForest     12                   4           0.333333  0.377925
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.041125  0.364189           0.028099     0.270205
# 1           0.035784  0.364229           0.021373     0.288002
# 2           0.041883  0.363426           0.029161     0.281954
# 3           0.024349  0.355959           0.016959     0.317267
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.076030  ...   0.357569            0.056686          0.379710
# 1              0.077092  ...   0.356890            0.057451          0.378512
# 2              0.070186  ...   0.361690            0.058099          0.379752
# 3              0.045527  ...   0.333443            0.055408          0.359738
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.022790                              0.39685
# 1                   0.020368                              0.39685
# 2                   0.024339                              0.39685
# 3                   0.014325                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.003688
# 1                                  -0.001647
# 2                                  -0.003446
# 3                                  -0.018925
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.033551
# 1                                           0.035626
# 2                                           0.034266
# 3                                           0.043231
#
# [4 rows x 30 columns]
