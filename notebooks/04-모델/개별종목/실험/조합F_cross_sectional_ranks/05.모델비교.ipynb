# %% [markdown]
# # 개별종목 조합F 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | LightGBM ⭐ | 0.3873 | 0.3969 | -0.0096 | 0.3793 | 0.3600 | **0.3748** |
# | 2 | XGBoost | 0.3923 | 0.3969 | -0.0045 | 0.3775 | 0.3394 | **0.3678** |
# | 3 | RandomForest | 0.3688 | 0.3969 | -0.0281 | 0.3568 | 0.3495 | **0.3575** |
# | 4 | LogisticRegression | 0.3944 | 0.3969 | -0.0024 | 0.3764 | 0.3011 | **0.3519** |
#
# 별표는 합의한 핵심지표 조화평균이 가장 높은 모델입니다. Accuracy 단독 순위가 아니라
# 하락 Recall까지 함께 반영하므로, 중립이나 상승 한쪽으로만 쏠린 모델을 피합니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,936행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 5행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['F']["model_summary"])
display(comparison)
# Out:
#                 model  folds  accuracy  accuracy_fold_std  macro_f1  \
# 0            LightGBM     12  0.387286           0.016325  0.379309
# 1             XGBoost     12  0.392346           0.024998  0.377531
# 2        RandomForest     12  0.368781           0.018198  0.356767
# 3  LogisticRegression     12  0.394425           0.031760  0.376382
#
#    macro_f1_fold_std  down_recall  down_recall_fold_std  core_harmonic_mean  \
# 0           0.014269     0.359999              0.019572            0.374772
# 1           0.018780     0.339434              0.032837            0.367774
# 2           0.012392     0.349477              0.032984            0.357467
# 3           0.022859     0.301066              0.031204            0.351892
#
#    core_harmonic_mean_fold_std  training_majority_baseline_accuracy  \
# 0                     0.011088                             0.396868
# 1                     0.021699                             0.396868
# 2                     0.016801                             0.396868
# 3                     0.026520                             0.396868
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                      0.054978
# 1                                      0.054978
# 2                                      0.054978
# 3                                      0.054978
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402772
# 1                             0.402772
# 2                             0.402772
# 3                             0.402772
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049799
# 1                                      0.049799
# 2                                      0.049799
# 3                                      0.049799
#
#    accuracy_minus_training_majority_baseline  \
# 0                                  -0.009582
# 1                                  -0.004522
# 2                                  -0.028087
# 3                                  -0.002442
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.048157
# 1                                           0.041006
# 2                                           0.045933
# 3                                           0.033485
