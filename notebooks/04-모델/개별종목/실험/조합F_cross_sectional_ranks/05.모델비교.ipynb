# %% [markdown]
# # 개별종목 조합F 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.3940 | 0.3969 | -0.0028 | 0.3760 | 4/12 | 0.0744 | 0.3852 |
# | 2 | XGBoost | 0.3925 | 0.3969 | -0.0043 | 0.3780 | 6/12 | 0.0757 | 0.3903 |
# | 3 | LightGBM | 0.3907 | 0.3969 | -0.0062 | 0.3803 | 6/12 | 0.0772 | 0.3871 |
# | 4 | RandomForest | 0.3698 | 0.3969 | -0.0270 | 0.3612 | 5/12 | 0.0476 | 0.3655 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['F']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   4           0.333333  0.394039
# 1             XGBoost     12                   6           0.500000  0.392507
# 2            LightGBM     12                   6           0.500000  0.390690
# 3        RandomForest     12                   5           0.416667  0.369839
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.031651  0.375996           0.022700     0.300173
# 1           0.022438  0.377995           0.017555     0.339776
# 2           0.023066  0.380320           0.015930     0.357743
# 3           0.015465  0.361236           0.013570     0.360885
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.030784  ...   0.341246            0.050055          0.385175
# 1              0.033642  ...   0.346493            0.051509          0.390340
# 2              0.026454  ...   0.342341            0.048178          0.387067
# 3              0.023458  ...   0.321738            0.044720          0.365541
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.020057                              0.39685
# 1                   0.017510                              0.39685
# 2                   0.014701                              0.39685
# 3                   0.011057                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                  -0.002811
# 1                                  -0.004343
# 2                                  -0.006160
# 3                                  -0.027011
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.033199
# 1                                           0.042723
# 2                                           0.042323
# 3                                           0.050075
#
# [4 rows x 30 columns]
