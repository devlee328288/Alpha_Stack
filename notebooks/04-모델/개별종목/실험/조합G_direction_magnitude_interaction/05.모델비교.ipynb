# %% [markdown]
# # 개별종목 조합G 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4107 | 0.3969 | +0.0138 | 0.3675 | 7/12 | 0.0820 | 0.3941 |
# | 2 | XGBoost | 0.4038 | 0.3969 | +0.0070 | 0.3740 | 7/12 | 0.0794 | 0.3934 |
# | 3 | LightGBM | 0.4000 | 0.3969 | +0.0031 | 0.3743 | 6/12 | 0.0748 | 0.3891 |
# | 4 | RandomForest | 0.3728 | 0.3969 | -0.0241 | 0.3567 | 3/12 | 0.0417 | 0.3677 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['G']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   7           0.583333  0.410689
# 1             XGBoost     12                   7           0.583333  0.403802
# 2            LightGBM     12                   6           0.500000  0.399955
# 3        RandomForest     12                   3           0.250000  0.372760
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.042419  0.367509           0.029203     0.239923
# 1           0.040513  0.374020           0.017765     0.302014
# 2           0.034642  0.374279           0.019338     0.318333
# 3           0.024481  0.356728           0.018198     0.331952
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.080363  ...   0.350487            0.049096          0.394098
# 1              0.097937  ...   0.353038            0.049680          0.393378
# 2              0.093305  ...   0.347711            0.051923          0.389079
# 3              0.061427  ...   0.328699            0.048205          0.367740
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.018838                              0.39685
# 1                   0.019724                              0.39685
# 2                   0.021336                              0.39685
# 3                   0.017221                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.013839
# 1                                   0.006952
# 2                                   0.003105
# 3                                  -0.024091
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.030409
# 1                                           0.028418
# 2                                           0.034867
# 3                                           0.043766
#
# [4 rows x 30 columns]
