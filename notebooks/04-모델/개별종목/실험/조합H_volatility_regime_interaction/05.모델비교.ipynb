# %% [markdown]
# # 개별종목 조합H 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4071 | 0.3969 | +0.0103 | 0.3690 | 6/12 | 0.0783 | 0.3921 |
# | 2 | XGBoost | 0.4048 | 0.3969 | +0.0080 | 0.3749 | 7/12 | 0.0802 | 0.3883 |
# | 3 | LightGBM | 0.3999 | 0.3969 | +0.0030 | 0.3717 | 7/12 | 0.0731 | 0.3863 |
# | 4 | RandomForest | 0.3712 | 0.3969 | -0.0256 | 0.3578 | 3/12 | 0.0416 | 0.3630 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['H']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   6           0.500000  0.407124
# 1             XGBoost     12                   7           0.583333  0.404831
# 2            LightGBM     12                   7           0.583333  0.399870
# 3        RandomForest     12                   3           0.250000  0.371228
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.039713  0.369021           0.019142     0.245756
# 1           0.039344  0.374876           0.023752     0.314274
# 2           0.030735  0.371689           0.022220     0.329735
# 3           0.019904  0.357787           0.016285     0.343636
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.079671  ...   0.347342            0.048511          0.392052
# 1              0.090874  ...   0.349628            0.049475          0.388310
# 2              0.097119  ...   0.346016            0.051467          0.386287
# 3              0.047332  ...   0.326044            0.050824          0.363014
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.019917                              0.39685
# 1                   0.020960                              0.39685
# 2                   0.020406                              0.39685
# 3                   0.014071                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.010274
# 1                                   0.007981
# 2                                   0.003020
# 3                                  -0.025623
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.027901
# 1                                           0.031757
# 2                                           0.033856
# 3                                           0.044737
#
# [4 rows x 30 columns]
