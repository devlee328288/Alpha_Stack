# %% [markdown]
# # 개별종목 조합A 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | LightGBM ⭐ | 0.4074 | 0.3969 | +0.0105 | 0.3769 | 0.3291 | **0.3572** |
# | 2 | RandomForest | 0.3853 | 0.3969 | -0.0115 | 0.3618 | 0.3335 | **0.3546** |
# | 3 | XGBoost | 0.4104 | 0.3969 | +0.0135 | 0.3737 | 0.2953 | **0.3384** |
# | 4 | LogisticRegression | 0.4140 | 0.3969 | +0.0172 | 0.3701 | 0.2828 | **0.3331** |
#
# 별표는 합의한 핵심지표 조화평균이 가장 높은 모델입니다. Accuracy 단독 순위가 아니라
# 하락 Recall까지 함께 반영하므로, 중립이나 상승 한쪽으로만 쏠린 모델을 피합니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,936행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 5행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['A']["model_summary"])
display(comparison)
# Out:
#                 model  folds  accuracy  accuracy_fold_std  macro_f1  \
# 0            LightGBM     12  0.407370           0.038494  0.376950
# 1        RandomForest     12  0.385344           0.030775  0.361762
# 2             XGBoost     12  0.410380           0.041757  0.373704
# 3  LogisticRegression     12  0.414041           0.043018  0.370098
#
#    macro_f1_fold_std  down_recall  down_recall_fold_std  core_harmonic_mean  \
# 0           0.015545     0.329145              0.106536            0.357203
# 1           0.013259     0.333549              0.070670            0.354588
# 2           0.020515     0.295316              0.111217            0.338379
# 3           0.027403     0.282766              0.109217            0.333096
#
#    core_harmonic_mean_fold_std  training_majority_baseline_accuracy  \
# 0                     0.050868                             0.396868
# 1                     0.027683                             0.396868
# 2                     0.066365                             0.396868
# 3                     0.068835                             0.396868
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                      0.054978
# 1                                      0.054978
# 2                                      0.054978
# 3                                      0.054978
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402772
# 1                             0.402772
# 2                             0.402772
# 3                             0.402772
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049799
# 1                                      0.049799
# 2                                      0.049799
# 3                                      0.049799
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.010502
# 1                                  -0.011523
# 2                                   0.013512
# 3                                   0.017173
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.024173
# 1                                           0.030708
# 2                                           0.022853
# 3                                           0.025866
