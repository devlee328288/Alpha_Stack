# %% [markdown]
# # 개별종목 조합A 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4141 | 0.3969 | +0.0172 | 0.3702 | 8/12 | 0.0873 | 0.3982 |
# | 2 | XGBoost | 0.4097 | 0.3969 | +0.0128 | 0.3725 | 6/12 | 0.0834 | 0.3974 |
# | 3 | LightGBM | 0.4071 | 0.3969 | +0.0103 | 0.3757 | 6/12 | 0.0827 | 0.3926 |
# | 4 | RandomForest | 0.3888 | 0.3969 | -0.0080 | 0.3659 | 5/12 | 0.0591 | 0.3738 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['A']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                   8           0.666667  0.414090
# 1             XGBoost     12                   6           0.500000  0.409671
# 2            LightGBM     12                   6           0.500000  0.407119
# 3        RandomForest     12                   5           0.416667  0.388846
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.043167  0.370155           0.027155     0.282798
# 1           0.042051  0.372535           0.021518     0.294170
# 2           0.036739  0.375716           0.019020     0.328231
# 3           0.030617  0.365936           0.017345     0.333712
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.108112  ...   0.353439            0.053723          0.398177
# 1              0.112713  ...   0.357890            0.050756          0.397372
# 2              0.112199  ...   0.353811            0.049641          0.392611
# 3              0.066856  ...   0.334089            0.048631          0.373779
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.015518                              0.39685
# 1                   0.014204                              0.39685
# 2                   0.013607                              0.39685
# 3                   0.013918                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.017240
# 1                                   0.012821
# 2                                   0.010269
# 3                                  -0.008004
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.025709
# 1                                           0.022945
# 2                                           0.027108
# 3                                           0.033980
#
# [4 rows x 30 columns]
