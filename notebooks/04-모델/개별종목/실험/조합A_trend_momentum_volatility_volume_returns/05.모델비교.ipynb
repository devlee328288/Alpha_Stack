# %% [markdown]
# # 개별종목 조합A 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | RandomForest ⭐ | 0.3831 | 0.3851 | -0.0020 | 0.3649 | 0.3361 | **0.3555** |
# | 2 | LightGBM | 0.3979 | 0.3851 | +0.0128 | 0.3697 | 0.3187 | **0.3449** |
# | 3 | XGBoost | 0.3984 | 0.3851 | +0.0133 | 0.3649 | 0.2785 | **0.3234** |
# | 4 | LogisticRegression | 0.4009 | 0.3851 | +0.0158 | 0.3549 | 0.2624 | **0.3104** |
#
# 별표는 합의한 핵심지표 조화평균이 가장 높은 모델입니다. Accuracy 단독 순위가 아니라
# 하락 Recall까지 함께 반영하므로, 중립이나 상승 한쪽으로만 쏠린 모델을 피합니다.
#
# ## 데이터 규모
#
# - 모델 행: 171,557행
# - 거래일: 3,552일
# - 후보에 포함된 종목: 162종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 5행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3851
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.3976
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['A']["model_summary"])
display(comparison)
# Out:
#                 model  folds  accuracy  accuracy_fold_std  macro_f1  \
# 0        RandomForest     12  0.383140           0.026144  0.364905
# 1            LightGBM     12  0.397868           0.032861  0.369750
# 2             XGBoost     12  0.398439           0.034212  0.364915
# 3  LogisticRegression     12  0.400939           0.035280  0.354941
#
#    macro_f1_fold_std  down_recall  down_recall_fold_std  core_harmonic_mean  \
# 0           0.014398     0.336069              0.077032            0.355515
# 1           0.019905     0.318659              0.130029            0.344940
# 2           0.022211     0.278456              0.122801            0.323398
# 3           0.028864     0.262378              0.132238            0.310415
#
#    core_harmonic_mean_fold_std  training_majority_baseline_accuracy  \
# 0                     0.026690                             0.385115
# 1                     0.055484                             0.385115
# 2                     0.063873                             0.385115
# 3                     0.071926                             0.385115
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                      0.056247
# 1                                      0.056247
# 2                                      0.056247
# 3                                      0.056247
#
#    validation_majority_oracle_accuracy  \
# 0                             0.397559
# 1                             0.397559
# 2                             0.397559
# 3                             0.397559
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.044893
# 1                                      0.044893
# 2                                      0.044893
# 3                                      0.044893
#
#    accuracy_minus_training_majority_baseline  \
# 0                                  -0.001975
# 1                                   0.012753
# 2                                   0.013324
# 3                                   0.015824
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.035388
# 1                                           0.031849
# 2                                           0.032112
# 3                                           0.026421
