# %% [markdown]
# # 개별종목 조합F — LightGBM
#
# ## 실험 목적
#
# KOSPI200 방향이 상승·보합·하락 중 어디인지 정해졌을 때, 같은 방향일 확률이 높은
# 개별종목을 찾기 위한 3분류 모델입니다.
#
# 후보는 매 거래일 **KOSPI 세부 업종지수 시가총액 상위 10개 × 업종별 KOSPI 보통주
# 시가총액 상위 5개**로 먼저 고정합니다. 업종의 미래 방향을 따로 예측하는 구조는 아닙니다.
#
# ## 공통 조건
#
# | 항목 | 값 |
# |---|---|
# | 원천 | HF `full/daily_price_dev.parquet`, `full/index_price_dev.parquet` |
# | 홀드아웃 | `20240901` 이후 접근 금지 |
# | 라벨 | T일 판단 → T+1 `adj_open` 진입 → T+6 `adj_open` 평가, 종목 ±2% |
# | 외부 검증 | 날짜 그룹 expanding 12폴드 |
# | 최초 학습 | 750거래일 |
# | 검증·gap | 폴드당 60거래일 · 직전 5거래일 제거 |
# | class weight | 각 외부 폴드 내부에서 `None`과 `balanced` 재비교 |
# | 선정 지표 | Accuracy·Macro F1·하락 Recall 조화평균 |
#
# ## OOS 결과
#
# | Accuracy | Macro F1 | 하락 Recall | 핵심지표 조화평균 |
# |---:|---:|---:|---:|
# | 0.3873 | 0.3793 | 0.3600 | **0.3748** |
#
# 아래 셀은 저장된 실측 리포트에서 이 모델의 폴드 결과와 class weight 선택 횟수를 다시
# 읽습니다. 학습 구현은 `models/stock_experiment.py`, 피처·라벨은
# `features/stock_model_dataset.py`가 정본입니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
combination = 'F'
model_name = 'LightGBM'

combination_report = report["combinations"][combination]
folds = pd.DataFrame(combination_report["outer_fold_results"])
display(folds.loc[folds["model"].eq(model_name)].reset_index(drop=True))

weights = pd.DataFrame(combination_report["selected_class_weight_counts"])
display(weights.loc[weights["model"].eq(model_name)].reset_index(drop=True))
# Out:
#        model  fold selected_class_weight  train_dates  valid_dates  \
# 0   LightGBM     1              balanced          750           60
# 1   LightGBM     2              balanced          980           60
# 2   LightGBM     3              balanced         1210           60
# 3   LightGBM     4              balanced         1439           60
# 4   LightGBM     5              balanced         1669           60
# 5   LightGBM     6              balanced         1899           60
# 6   LightGBM     7              balanced         2129           60
# 7   LightGBM     8              balanced         2359           60
# 8   LightGBM     9              balanced         2589           60
# 9   LightGBM    10              balanced         2818           60
# 10  LightGBM    11              balanced         3048           60
# 11  LightGBM    12              balanced         3278           60
#
#     train_rows  valid_rows train_end valid_start valid_end  ...  down_recall  \
# 0        35611        2875  20140207    20140217  20140514  ...     0.342606
# 1        46623        2785  20150115    20150123  20150421  ...     0.365887
# 2        57309        2919  20151217    20151228  20160328  ...     0.359823
# 3        68495        2848  20161124    20161202  20170228  ...     0.364883
# 4        79206        2720  20171103    20171113  20180207  ...     0.345266
# 5        89642        2776  20181016    20181024  20190118  ...     0.333333
# 6       100686        2928  20190920    20190930  20191224  ...     0.355491
# 7       111867        2940  20200825    20200902  20201130  ...     0.405941
# 8       123092        2916  20210729    20210806  20211105  ...     0.356201
# 9       134110        2898  20220706    20220714  20221012  ...     0.359303
# 10      145369        3000  20230612    20230620  20230912  ...     0.346719
# 11      156753        2938  20240521    20240529  20240822  ...     0.384537
#
#     core_harmonic_mean  training_majority_class  \
# 0             0.371812                        0
# 1             0.375163                        0
# 2             0.358228                        0
# 3             0.383791                        0
# 4             0.368870                        0
# 5             0.375175                        0
# 6             0.380236                        0
# 7             0.392623                        0
# 8             0.382140                        0
# 9             0.353653                        0
# 10            0.371216                        0
# 11            0.384357                        0
#
#     training_majority_baseline_accuracy  validation_majority_class  \
# 0                              0.501217                          0
# 1                              0.397846                          0
# 2                              0.376156                          0
# 3                              0.461728                          0
# 4                              0.390074                          0
# 5                              0.372478                          0
# 6                              0.478142                          0
# 7                              0.347619                          1
# 8                              0.391632                          0
# 9                              0.345411                         -1
# 10                             0.372333                          0
# 11                             0.327774                          1
#
#     validation_majority_oracle_accuracy  validation_down_rate  \
# 0                              0.501217              0.237565
# 1                              0.397846              0.261041
# 2                              0.376156              0.310380
# 3                              0.461728              0.255969
# 4                              0.390074              0.318382
# 5                              0.372478              0.291787
# 6                              0.478142              0.236339
# 7                              0.377551              0.274830
# 8                              0.391632              0.389918
# 9                              0.376467              0.376467
# 10                             0.372333              0.340333
# 11                             0.337645              0.334581
#
#     validation_neutral_rate  validation_up_rate  \
# 0                  0.501217            0.261217
# 1                  0.397846            0.341113
# 2                  0.376156            0.313464
# 3                  0.461728            0.282303
# 4                  0.390074            0.291544
# 5                  0.372478            0.335735
# 6                  0.478142            0.285519
# 7                  0.347619            0.377551
# 8                  0.391632            0.218450
# 9                  0.345411            0.278123
# 10                 0.372333            0.287333
# 11                 0.327774            0.337645
#
#     accuracy_minus_training_majority_baseline
# 0                                   -0.101217
# 1                                   -0.015440
# 2                                   -0.016444
# 3                                   -0.063202
# 4                                   -0.004779
# 5                                    0.032061
# 6                                   -0.074454
# 7                                    0.039116
# 8                                    0.008230
# 9                                    0.008282
# 10                                   0.014667
# 11                                   0.058203
#
# [12 rows x 22 columns]
#       model selected_class_weight  folds
# 0  LightGBM              balanced     12
