# %% [markdown]
# # 개별종목 조합K 4모델 비교
#
# ## 후보·평가 흐름
#
# `KOSPI200 3분류 → 시총 기준 업종 Top 10 → 업종별 시총 Top 5 → 최대 50종목의
# 3분류 확률 → 지수 예측 클래스에 해당하는 확률로 랭킹` 순서입니다.
#
# ## OOS 비교
#
# | 순위 | 모델 | Accuracy | 학습 최빈 기준선 | 기준선 대비 | Macro F1 | 기준선 승리 | MCC | Macro PR-AUC |
# |---:|---|---:|---:|---:|---:|---:|---:|---:|
# | 1 | LogisticRegression ⭐ | 0.4211 | 0.3969 | +0.0243 | 0.3781 | 10/12 | 0.0994 | 0.4018 |
# | 2 | XGBoost | 0.4130 | 0.3969 | +0.0161 | 0.3755 | 6/12 | 0.0888 | 0.3997 |
# | 3 | LightGBM | 0.4092 | 0.3969 | +0.0124 | 0.3761 | 7/12 | 0.0853 | 0.3957 |
# | 4 | RandomForest | 0.3950 | 0.3969 | -0.0019 | 0.3701 | 5/12 | 0.0667 | 0.3784 |
#
# 별표는 ADR 0007의 `기준선 대비 Accuracy → Macro F1 → 기준선 승리 폴드 수` 순서로
# 선정한 모델입니다. 하락 Recall과 기존 조화평균은 진단값으로 결과에 계속 남깁니다.
#
# ## 데이터 규모
#
# - 모델 행: 159,900행
# - 거래일: 3,343일
# - 후보에 포함된 종목: 157종목
# - 수정주가 품질 의심 제거: 0행
# - KRX 등락률과 일치해 보존한 실제 극단 사건: 4행
# - 폴드별 학습 최빈 Accuracy 기준선 평균: 0.3969
# - 검증 최빈 Accuracy 사후 참고값 평균: 0.4028
#
# 학습 최빈 기준선만 모델 비교에 사용합니다. 검증 최빈 값은 해당 폴드의 정답 분포를 본
# `oracle` 통계이므로 성능 판정에는 사용하지 않습니다.

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while ROOT.parent != ROOT and not (ROOT / "reports" / "stock_feature_combinations.json").exists():
    ROOT = ROOT.parent
report_path = ROOT / "reports" / "stock_feature_combinations.json"
report = json.loads(report_path.read_text(encoding="utf-8"))
comparison = pd.DataFrame(report["combinations"]['K']["model_summary"])
display(comparison)
# Out:
#                 model  folds  baseline_win_folds  baseline_win_rate  accuracy  \
# 0  LogisticRegression     12                  10           0.833333  0.421137
# 1             XGBoost     12                   6           0.500000  0.412959
# 2            LightGBM     12                   7           0.583333  0.409218
# 3        RandomForest     12                   5           0.416667  0.394988
#
#    accuracy_fold_std  macro_f1  macro_f1_fold_std  down_recall  \
# 0           0.038256  0.378082           0.029841     0.305842
# 1           0.039950  0.375466           0.024435     0.301517
# 2           0.035418  0.376116           0.021628     0.333945
# 3           0.026823  0.370087           0.015977     0.340084
#
#    down_recall_fold_std  ...  pr_auc_up  pr_auc_up_fold_std  pr_auc_macro_ovr  \
# 0              0.118425  ...   0.354512            0.055019          0.401781
# 1              0.118443  ...   0.357056            0.052777          0.399652
# 2              0.115659  ...   0.353601            0.048091          0.395687
# 3              0.075315  ...   0.337526            0.050954          0.378403
#
#    pr_auc_macro_ovr_fold_std  training_majority_baseline_accuracy  \
# 0                   0.013404                              0.39685
# 1                   0.015079                              0.39685
# 2                   0.014608                              0.39685
# 3                   0.013407                              0.39685
#
#    training_majority_baseline_accuracy_fold_std  \
# 0                                       0.05498
# 1                                       0.05498
# 2                                       0.05498
# 3                                       0.05498
#
#    validation_majority_oracle_accuracy  \
# 0                             0.402755
# 1                             0.402755
# 2                             0.402755
# 3                             0.402755
#
#    validation_majority_oracle_accuracy_fold_std  \
# 0                                      0.049804
# 1                                      0.049804
# 2                                      0.049804
# 3                                      0.049804
#
#    accuracy_minus_training_majority_baseline  \
# 0                                   0.024287
# 1                                   0.016109
# 2                                   0.012367
# 3                                  -0.001862
#
#    accuracy_minus_training_majority_baseline_fold_std
# 0                                           0.029175
# 1                                           0.027734
# 2                                           0.026847
# 3                                           0.034684
#
# [4 rows x 30 columns]
