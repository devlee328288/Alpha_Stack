# %% [markdown]
# # 조합A · LogisticRegression long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합A_rsi14_bb_bandwidth_hv20_vol_ratio20/01.LogisticRegression.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 8 | False | 0.4208 | +0.0236 | 4/12 | 0.4277 | 0.3849 | 0.4440 | 278 | -0.1002 |
# | Daily_Return + 5Day_Return | 9 | False | 0.4028 | +0.0056 | 4/12 | 0.4220 | 0.3495 | 0.4772 | 329 | -0.2926 |
# | 5Day_Return | 10 | False | 0.4097 | +0.0125 | 4/12 | 0.4218 | 0.3517 | 0.4772 | 327 | -0.2792 |
# | Daily_Return | 11 | False | 0.4375 | +0.0403 | 5/12 | 0.4131 | 0.3821 | 0.4440 | 280 | -0.3542 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.4208 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | +0.0236 |
# | 기준선 승리 | 4/12 |
# | Macro F1 | 0.3593 |
# | 상승 PR-AUC | 0.4277 |
# | 상승 Precision | 0.3849 |
# | 상승 Recall | 0.4440 |
# | 매수 신호 | 278 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | -0.1002 |
# | 상승 임계값 중앙값 | 0.3500 |
# | 상승 임계값 범위 | 0.2250~0.4500 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
