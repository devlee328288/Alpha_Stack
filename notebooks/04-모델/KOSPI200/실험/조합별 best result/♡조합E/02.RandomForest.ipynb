# %% [markdown]
# # 조합E · RandomForest long-only best result
#
# 선정 실험: **5Day_Return**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합E_option5_volatility_only/조합E + 5Day_Return/02.RandomForest.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 5Day_Return **(선정)** | 13 | False | 0.3750 | -0.0222 | 4/12 | 0.4042 | 0.3882 | 0.4108 | 255 | 0.4703 |
# | 기본 조합 | 16 | False | 0.3764 | -0.0208 | 7/12 | 0.4006 | 0.3774 | 0.4025 | 257 | 1.0684 |
# | Daily_Return + 5Day_Return | 18 | False | 0.3611 | -0.0361 | 6/12 | 0.3983 | 0.3539 | 0.4523 | 308 | 0.5088 |
# | Daily_Return | 20 | False | 0.3556 | -0.0417 | 6/12 | 0.3964 | 0.3653 | 0.4108 | 271 | 0.2481 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3750 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0222 |
# | 기준선 승리 | 4/12 |
# | Macro F1 | 0.3718 |
# | 상승 PR-AUC | 0.4042 |
# | 상승 Precision | 0.3882 |
# | 상승 Recall | 0.4108 |
# | 매수 신호 | 255 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.4703 |
# | 상승 임계값 중앙값 | 0.4125 |
# | 상승 임계값 범위 | 0.2000~0.6250 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
