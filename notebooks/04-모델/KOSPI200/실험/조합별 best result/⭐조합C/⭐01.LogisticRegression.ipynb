# %% [markdown]
# # 조합C · LogisticRegression long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합C_sma_gap_macd_rsi_bb_hv_volume/01.LogisticRegression.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 1 | True | 0.4542 | +0.0569 | 7/12 | 0.3965 | 0.4221 | 0.5394 | 308 | 0.2332 |
# | Daily_Return | 3 | True | 0.4583 | +0.0611 | 7/12 | 0.3930 | 0.4351 | 0.4730 | 262 | 0.3442 |
# | 5Day_Return | 19 | False | 0.4306 | +0.0333 | 6/12 | 0.3968 | 0.3944 | 0.5270 | 322 | 0.2111 |
# | Daily_Return + 5Day_Return | 23 | False | 0.4278 | +0.0306 | 5/12 | 0.3956 | 0.3946 | 0.5436 | 332 | 0.2349 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.4542 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | +0.0569 |
# | 기준선 승리 | 7/12 |
# | Macro F1 | 0.4167 |
# | 상승 PR-AUC | 0.3965 |
# | 상승 Precision | 0.4221 |
# | 상승 Recall | 0.5394 |
# | 매수 신호 | 308 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.2332 |
# | 상승 임계값 중앙값 | 0.3375 |
# | 상승 임계값 범위 | 0.2000~0.4500 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
