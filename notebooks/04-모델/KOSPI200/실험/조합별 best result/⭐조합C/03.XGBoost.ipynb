# %% [markdown]
# # 조합C · XGBoost long-only best result
#
# 선정 실험: **Daily_Return**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합C_sma_gap_macd_rsi_bb_hv_volume/조합C + Daily_Return/03.XGBoost.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | Daily_Return **(선정)** | 65 | False | 0.3861 | -0.0111 | 5/12 | 0.3658 | 0.3900 | 0.4191 | 259 | 0.0191 |
# | Daily_Return + 5Day_Return | 66 | False | 0.3611 | -0.0361 | 6/12 | 0.3656 | 0.3423 | 0.3154 | 222 | -0.1658 |
# | 기본 조합 | 70 | False | 0.4042 | +0.0069 | 5/12 | 0.3608 | 0.4241 | 0.3942 | 224 | 0.3407 |
# | 5Day_Return | 72 | False | 0.3681 | -0.0292 | 4/12 | 0.3554 | 0.3568 | 0.3568 | 241 | -0.2663 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3861 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0111 |
# | 기준선 승리 | 5/12 |
# | Macro F1 | 0.3508 |
# | 상승 PR-AUC | 0.3658 |
# | 상승 Precision | 0.3900 |
# | 상승 Recall | 0.4191 |
# | 매수 신호 | 259 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.0191 |
# | 상승 임계값 중앙값 | 0.3875 |
# | 상승 임계값 범위 | 0.2250~0.4750 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
