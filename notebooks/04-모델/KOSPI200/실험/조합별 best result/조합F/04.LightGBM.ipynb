# %% [markdown]
# # 조합F · LightGBM long-only best result
#
# 선정 실험: **Daily_Return + 5Day_Return**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합F_option6_maximum/조합F + Daily_Return + 5Day_Return/04.LightGBM.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | Daily_Return + 5Day_Return **(선정)** | 38 | False | 0.3250 | -0.0722 | 2/12 | 0.3864 | 0.3527 | 0.4274 | 292 | -0.3207 |
# | 5Day_Return | 56 | False | 0.3708 | -0.0264 | 5/12 | 0.3726 | 0.3816 | 0.4813 | 304 | 0.1130 |
# | Daily_Return | 68 | False | 0.3486 | -0.0486 | 3/12 | 0.3636 | 0.3640 | 0.4108 | 272 | -0.0115 |
# | 기본 조합 | 73 | False | 0.3458 | -0.0514 | 5/12 | 0.3548 | 0.3725 | 0.3942 | 255 | -0.3213 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3250 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0722 |
# | 기준선 승리 | 2/12 |
# | Macro F1 | 0.3100 |
# | 상승 PR-AUC | 0.3864 |
# | 상승 Precision | 0.3527 |
# | 상승 Recall | 0.4274 |
# | 매수 신호 | 292 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | -0.3207 |
# | 상승 임계값 중앙값 | 0.4125 |
# | 상승 임계값 범위 | 0.2000~0.7500 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
