# %% [markdown]
# # 조합F · RandomForest long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합F_option6_maximum/02.RandomForest.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 80 | False | 0.3667 | -0.0306 | 5/12 | 0.3495 | 0.3710 | 0.3402 | 221 | 0.3457 |
# | Daily_Return | 82 | False | 0.3444 | -0.0528 | 4/12 | 0.3464 | 0.3696 | 0.4232 | 276 | 0.0545 |
# | Daily_Return + 5Day_Return | 84 | False | 0.3528 | -0.0444 | 2/12 | 0.3447 | 0.3406 | 0.3900 | 276 | -0.0296 |
# | 5Day_Return | 86 | False | 0.3361 | -0.0611 | 4/12 | 0.3404 | 0.3480 | 0.4606 | 319 | -0.1811 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3667 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0306 |
# | 기준선 승리 | 5/12 |
# | Macro F1 | 0.3495 |
# | 상승 PR-AUC | 0.3495 |
# | 상승 Precision | 0.3710 |
# | 상승 Recall | 0.3402 |
# | 매수 신호 | 221 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.3457 |
# | 상승 임계값 중앙값 | 0.5125 |
# | 상승 임계값 범위 | 0.2000~0.6750 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
