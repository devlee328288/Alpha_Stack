# %% [markdown]
# # 조합D · RandomForest long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합D_option2_volatility_focus/02.RandomForest.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 51 | False | 0.3653 | -0.0319 | 4/12 | 0.3759 | 0.3629 | 0.5270 | 350 | 0.0662 |
# | Daily_Return + 5Day_Return | 59 | False | 0.3347 | -0.0625 | 3/12 | 0.3706 | 0.3487 | 0.4398 | 304 | 0.0456 |
# | Daily_Return | 62 | False | 0.3389 | -0.0583 | 4/12 | 0.3676 | 0.3587 | 0.4689 | 315 | -0.0529 |
# | 5Day_Return | 67 | False | 0.3569 | -0.0403 | 5/12 | 0.3645 | 0.3606 | 0.5311 | 355 | 0.0984 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3653 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0319 |
# | 기준선 승리 | 4/12 |
# | Macro F1 | 0.3473 |
# | 상승 PR-AUC | 0.3759 |
# | 상승 Precision | 0.3629 |
# | 상승 Recall | 0.5270 |
# | 매수 신호 | 350 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.0662 |
# | 상승 임계값 중앙값 | 0.3125 |
# | 상승 임계값 범위 | 0.2000~0.5250 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
