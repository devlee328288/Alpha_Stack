# %% [markdown]
# # 조합D · LightGBM long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합D_option2_volatility_focus/04.LightGBM.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 15 | False | 0.3514 | -0.0458 | 3/12 | 0.4009 | 0.3569 | 0.4398 | 297 | 0.0837 |
# | Daily_Return + 5Day_Return | 29 | False | 0.3569 | -0.0403 | 5/12 | 0.3922 | 0.3725 | 0.3942 | 255 | 0.3349 |
# | Daily_Return | 34 | False | 0.3431 | -0.0542 | 3/12 | 0.3882 | 0.3689 | 0.5311 | 347 | 0.0097 |
# | 5Day_Return | 53 | False | 0.3264 | -0.0708 | 3/12 | 0.3748 | 0.3456 | 0.4689 | 327 | -0.0334 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.3514 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | -0.0458 |
# | 기준선 승리 | 3/12 |
# | Macro F1 | 0.3423 |
# | 상승 PR-AUC | 0.4009 |
# | 상승 Precision | 0.3569 |
# | 상승 Recall | 0.4398 |
# | 매수 신호 | 297 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.0837 |
# | 상승 임계값 중앙값 | 0.3500 |
# | 상승 임계값 범위 | 0.2000~0.7750 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
