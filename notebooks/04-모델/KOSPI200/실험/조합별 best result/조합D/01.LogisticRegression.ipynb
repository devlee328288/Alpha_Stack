# %% [markdown]
# # 조합D · LogisticRegression long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합D_option2_volatility_focus/01.LogisticRegression.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 24 | False | 0.4361 | +0.0389 | 5/12 | 0.3947 | 0.4125 | 0.4108 | 240 | -0.2921 |
# | 5Day_Return | 30 | False | 0.4250 | +0.0278 | 6/12 | 0.3907 | 0.3862 | 0.4647 | 290 | 0.2559 |
# | Daily_Return | 36 | False | 0.4069 | +0.0097 | 4/12 | 0.3867 | 0.3715 | 0.4979 | 323 | 0.2511 |
# | Daily_Return + 5Day_Return | 39 | False | 0.4139 | +0.0167 | 6/12 | 0.3851 | 0.3813 | 0.4730 | 299 | 0.0149 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.4361 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | +0.0389 |
# | 기준선 승리 | 5/12 |
# | Macro F1 | 0.4019 |
# | 상승 PR-AUC | 0.3947 |
# | 상승 Precision | 0.4125 |
# | 상승 Recall | 0.4108 |
# | 매수 신호 | 240 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | -0.2921 |
# | 상승 임계값 중앙값 | 0.3375 |
# | 상승 임계값 범위 | 0.2250~0.4750 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
