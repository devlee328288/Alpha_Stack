# %% [markdown]
# # 조합B · LogisticRegression long-only best result
#
# 선정 실험: **기본 조합**
# 선정 기준: 운영 기준선 게이트 → 상승 PR-AUC → 비용 차감 ΔSharpe → 상승 Precision
# [피처·모델 원본 노트북](../../조합B_sma_gap_5_20_macd_hist_ratio_rsi14_hv20/01.LogisticRegression.ipynb)

# %% [markdown]
# ## 피처 변형 비교
#
# | 실험 | 전체 순위 | 게이트 | Accuracy | 기준선 대비 | 승리 폴드 | 상승 PR-AUC | 상승 Precision | 상승 Recall | 매수 신호 | ΔSharpe 중앙값 |
# |---|---:|---|---:|---:|---:|---:|---:|---:|---:|---:|
# | 기본 조합 **(선정)** | 2 | True | 0.4597 | +0.0625 | 7/12 | 0.3938 | 0.4231 | 0.5477 | 312 | 0.1144 |
# | 5Day_Return | 26 | False | 0.4639 | +0.0667 | 6/12 | 0.3939 | 0.4116 | 0.5021 | 294 | -0.0557 |
# | Daily_Return + 5Day_Return | 28 | False | 0.4639 | +0.0667 | 6/12 | 0.3937 | 0.4192 | 0.5062 | 291 | -0.0557 |
# | Daily_Return | 31 | False | 0.4556 | +0.0583 | 6/12 | 0.3903 | 0.4076 | 0.5311 | 314 | 0.0574 |

# %% [markdown]
# ## 선정 결과
#
# | 지표 | 값 |
# |---|---:|
# | Accuracy | 0.4597 |
# | 학습 최빈 기준선 | 0.3972 |
# | 기준선 대비 Accuracy | +0.0625 |
# | 기준선 승리 | 7/12 |
# | Macro F1 | 0.4048 |
# | 상승 PR-AUC | 0.3938 |
# | 상승 Precision | 0.4231 |
# | 상승 Recall | 0.5477 |
# | 매수 신호 | 312 |
# | 비용 차감 ΔSharpe 폴드 중앙값 | 0.1144 |
# | 상승 임계값 중앙값 | 0.3375 |
# | 상승 임계값 범위 | 0.2000~0.4250 |

# %% [markdown]
# ## 해석 범위
#
# 각 외부 폴드의 상승 임계값과 class weight는 그 폴드의 학습구간 안에 둔 내부 검증에서만 골랐다. 이 값은 개발구간 공통 OOS 결과이며 봉인 홀드아웃은 사용하지 않았다. 이슈 #203 확정 전까지는 잠정 비교 결과다.
